# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# remotes::install_github("zqfang/MuDataSeurat", force = T)
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Downloading GitHub repo zqfang/MuDataSeurat@HEAD
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Installing 68 packages: RcppEigen, sitmo, BH, RcppProgress, dqrng, RSpectra, RcppAnnoy, irlba, FNN, polyclip, deldir, spatstat.utils, spatstat.univar, spatstat.data, tensor, abind, goftest, spatstat.sparse, spatstat.random, spatstat.geom, plyr, parallelly, listenv, globals, RcppArmadillo, matrixStats, gridExtra, reshape2, future, future.apply, bitops, caTools, gtools, gplots, png, here, RcppTOML, crosstalk, lazyeval, zoo, igraph, reticulate, dotCall64, spam, progressr, sp, uwot, spatstat.explore, sctransform, scattermore, Rtsne, ROCR, RcppHNSW, RANN, plotly, pbapply, patchwork, lmtest, leiden, ica, ggridges, ggrepel, fitdistrplus, fastDummies, cowplot, SeuratObject, Seurat, hdf5r
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Installing packages into ‘/usr/local/lib/R/site-library’
# ...

# %%
import os
os.listdir("/content/drive/MyDrive/Regeneration-order/data/seurat-objects/")
# Out:
# ['WJ.Skeletal.RDS', 'cds.RDS', 'WJRegenRealigned.Integrated.RDS']

# %%
import os
os.listdir("/content/drive/MyDrive/Regeneration-order/data/scanpy-objects/")
# Out:
# []

# %%
# %%R
# ## skeletal subset
# srt.skeletal <- readRDS("/content/drive/MyDrive/Regeneration-order/data/seurat-objects/WJ.Skeletal.RDS")

# %%
# %%R
# MuDataSeurat::WriteH5AD(srt.skeletal, "/content/drive/MyDrive/Regeneration-order/data/scanpy-objects/WJ.Skeletal.h5ad", assay="RNA")
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: RNA Added .var['highly_variable'] with highly variable features to meta.featuresdata

# %%
os.listdir("/content/drive/MyDrive/Regeneration-order/data/scanpy-objects/")
# Out:
# ['WJ.Skeletal.h5ad']

# %%
# %%R
# installed.packages()
# Out:
#                  Package            LibPath
# abind            "abind"            "/usr/local/lib/R/site-library"
# BH               "BH"               "/usr/local/lib/R/site-library"
# bitops           "bitops"           "/usr/local/lib/R/site-library"
# caTools          "caTools"          "/usr/local/lib/R/site-library"
# cowplot          "cowplot"          "/usr/local/lib/R/site-library"
# crosstalk        "crosstalk"        "/usr/local/lib/R/site-library"
# deldir           "deldir"           "/usr/local/lib/R/site-library"
# dotCall64        "dotCall64"        "/usr/local/lib/R/site-library"
# dqrng            "dqrng"            "/usr/local/lib/R/site-library"
# fastDummies      "fastDummies"      "/usr/local/lib/R/site-library"
# fitdistrplus     "fitdistrplus"     "/usr/local/lib/R/site-library"
# FNN              "FNN"              "/usr/local/lib/R/site-library"
# future           "future"           "/usr/local/lib/R/site-library"
# ...
